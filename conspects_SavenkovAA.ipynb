# %% [markdown]
# # **Настройка Git**

# %%
# !git config --global user.name "yeetdream"
# !git config --global user.email "savenkovkaur@gmail.com"

# %% [markdown]
# # **Переходим в папку и подключимся к диску**

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# fatal: destination path 'InfoAmogus' already exists and is not an empty directory.

# %% [markdown]
# # **Где мы?**

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks'

# %% [markdown]
# # **Переместим файл на гит**

# %%
# !mv conspects_SavenkovAA.ipynb InfoAmogus/

# %% [markdown]
# # **Математика Python**
# * Сложение, вычитание, умножение(нацело div и с остатком mod), деление, возведение в степень "**",

# %%
a = 10
b = 5
print(a + b) # regular number 
print (float(a + b)) # floating number

c = 10 // 3 # Целочисленное деление 
print(c)

c = 10 % 3 # Остаток от деления 
print(c)
# Out:
# 15
# 15.0
# 3
# 1

# %%
a = round(7.5) # Округление до ближайшего четного
b = round(4.5) 
print(a, b)
# Out:
# 8 4

# %%
a = 50
b = 25
print(a/b)  # Результат деления всегда имеет тип float, число с плавающей точкой, даже если числа делятся нацело
# Out:
# 2.0

# %% [markdown]
# # **Наличие плавающего числа и модуль ABS**
#
# Введем к примеру 0.1, оно сохраняется в памяти как число с плавающей точкой и происходит преобразование. 0.1 — это десятичное число с основанием 10, но числа с плавающей точкой хранятся в двоичной записи. То есть основание 0.1 преобразуется из 10 в 2.
#
# Получающееся двоичное число может недостаточно  точно представлять исходное число с основанием 10. 0.1 — один из примеров. Двоичным представлением будет 0.0(0011). То есть 0.1 — это бесконечно повторяющееся десятичное число, записанное с основанием 2. То же происходит, когда в виде десятичного числа с основанием 10 записывается дробь ⅓. Получается бесконечно повторяющееся десятичное число 0.3(3).

# %%
a = 0.1 + 0.2
print(a) # Плавающее число
int(2.3) # float ==> integer - целые числа
# Округляет число в меньшую сторону, в отличие от классической математикиё

abs(-5) # Модуль числа
# Out:
# 0.30000000000000004
# 5

# %% [markdown]
# #**Каталог 'math'**
#
# Еще одна классная фича -  позволяет использовать дополнительные операции, о которых можно почитать [здесь](https://docs.python.org/3/library/math.html)

# %% [markdown]
# #**Commit**

# %%
cd /content/drive/MyDrive/Colab Notebooks/InfoAmogus
# Out:
# /content/drive/MyDrive/Colab Notebooks/InfoAmogus

# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git add .

# %%
# !git commit -m "Все доделал? замените мастер на мейн!"
# Out:
# On branch savenkovaa
# nothing to commit, working tree clean

# %%
token = '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'
username = 'sweitis'
repo = 'InfoAmogus'

# %%
# !git remote set-url origin https://{token}@github.com/{username}/{repo}.git
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git remote -v
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push origin savenkovaa
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
# !git pull origin savenkovaa
# Out:
# From https://github.com/sweitis/InfoAmogus
#  * branch            savenkovaa -> FETCH_HEAD
# Already up to date.

# %% [markdown]
# # **Журнал коммитов - log**

# %%
# !git log

# %%
# !git log --oneline

# %%
# !git log --graph

# %% [markdown]
# # **Ветки в Git - branches**

# %%
# !git checkout -b savenkovaa
# Out:
# fatal: A branch named 'savenkovaa' already exists.

# %%
# !git branch
# Out:
#   master
# * savenkovaa

# %%
# !git switch master
# Out:
# error: Your local changes to the following files would be overwritten by checkout:
# 	conspects_SavenkovAA.ipynb
# Please commit your changes or stash them before you switch branches.
# Aborting

# %%
# !git branch -M Main # меняем мастер на мейн(сперва чекаут сделай)

# %%
# !git branch -D yeetdream
# Out:
# Deleted branch yeetdream (was 6e0b8f8).
